# %%
import os
import copy
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
#from scipy.stats import multivariate_normal

from microsim.population import NHANESDirectSamplePopulation, get_nhanes_population

microsimDir = "/Users/deligkaris.1/OneDrive - The Ohio State University Wexner Medical Center/MICROSIM"
os.chdir(microsimDir+"/CODE/microsim")

year = 1999

# %%
pop = get_nhanes_population(1999)
pop.advance(1)

# %%
#%%time
#pop = NHANESDirectSamplePopulation(popSize, 1999)
#pop.advance(5, None, nWorkers=10)

# %%
df = pop.get_all_person_years_as_df()

# %%
df.head()
# Out:
#     name  raceEthnicity  education  gender  smokingStatus   afib    pvd   age  \
# 0  41787              3          5       1              0  False  False  77.0
# 1  41788              3          5       1              1  False  False  49.0
# 2  41789              5          4       2              0  False  False  19.0
# 3  41790              4          2       2              1  False   True  59.0
# 4  41791              4          3       1              2  False   True  43.0
#
#    alcoholPerWeek    hdl    bmi  totChol   trig  a1c    ldl  waist  \
# 0               2   54.0  24.90    215.0  128.0  4.7  136.0   98.0
# 1               3   42.0  29.10    279.0  347.0  5.5  168.0   99.9
# 2               0   61.0  22.56    153.0   80.0  5.1   71.0   81.6
# 3               0  105.0  29.39    245.0   62.0  5.8  127.0   90.7
# 4               2   51.0  30.94    140.0   45.0  5.5   80.0  108.0
#
#    creatinine         sbp        dbp  anyPhysicalActivity  statin  \
# 0         0.7  100.666667  56.666667                    0   False
# 1         0.8  122.000000  82.666667                    1   False
# 2         0.5  114.666667  68.000000                    1   False
# 3         0.6  125.333333  80.000000                    1   False
# 4         0.9  145.333333  96.000000                    1   False
#
#    antiHypertensiveCount
# 0                    0.0
# 1                    1.0
# 2                    0.0
# 3                    0.0
# 4                    0.0

# %%
df.to_csv(microsimDir+"/NOTEBOOKS/DATA/nhanes-normality-test-4.csv", index=False)

# %%
pop.print_baseline_summary()
# Out:
#                                                age   46.8
#                                                sbp  125.8
#                                                dbp   71.1
#                                                a1c    5.1
#                                                hdl   51.4
#                                                ldl  122.2
#                                               trig  147.5
#                                            totChol  201.4
#                                                bmi   27.6
#                                anyPhysicalActivity    0.6
#                                               afib    0.0
#                                              waist   95.3
#                                     alcoholPerWeek    1.8
#                                         creatinine    0.2
#                                                pvd    0.0
#               StaticRiskFactorsType.RACE_ETHNICITY
#                                                  3   0.43
#                                                  5   0.04
#                                                  4   0.19
#                                                  1   0.29
#                                                  2   0.06
#                    StaticRiskFactorsType.EDUCATION
#                                                  5   0.15
#                                                  4   0.31
#                                                  2   0.18
#                                                  3   0.20
#                                                  1   0.17
#                       StaticRiskFactorsType.GENDER
#                                                  1   0.47
#                                                  2   0.53
#               StaticRiskFactorsType.SMOKING_STATUS
#                                                  0   0.58
#                                                  1   0.24
#                                                  2   0.18
