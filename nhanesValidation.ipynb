# %% [markdown]
# # Microsim NHANES Validation
#
# The goal of this notebook is to illustrate how to run the NHANES validation simulations.

# %% [markdown]
# First we will import some libraries and switch to the Microsim code directory.

# %%
#we need the os module in order to change directory to the Microsim directory later
import os

#all the code needed to run the validation simulations is included in the validation.py file
#please see the validation.py file for more details
from microsim.validation import Validation

#change directory to the Microsim directory-this will be different for each user
#you will need to set microsimDir to be the directory where the Microsim code is in your computer
microsimDir = "/Users/deligkaris.1/OneDrive - The Ohio State University Wexner Medical Center/MICROSIM/CODE/microsim"
os.chdir(microsimDir)

# %% [markdown]
# Then, we will run all the validation code.
# The code runs the steps to validate:
# - baseline simulated population
# - vascular risk factors over time
# - CV event incidence and mortality
# - dementia incidence
# - blood pressure treatment effects

# %%
#feel free to modify the sampleSize and nWorkers parameters
#sampleSize should be at least 0.5 million for good treatment effect estimates
#use a smaller sampleSize if you just want to see how this works, eg 10,000
#nWorkers depends on how many cores you can use

#this command will run all NHANES validation tests but it will require a lot of memory
#Validation.nhanes()

#so for our purposes I will run the tests separately while controlling the population sizes and number of workers I utilize

# %%
#this first validation test is not computationally demanding (relatively)
Validation.nhanes_baseline_pop()
# Out:
# VALIDATION OF BASELINE SIMULATED POPULATION
# 2007 Nhanes
#                           Printing a summary of risk factors and default treatments...
#                           min      0.25    med     0.75     max    mean     sd
#                           -----------------------------------------------------
#                     age    18.0    32.0    45.0    58.0    80.0    45.8    17.2
#                     hdl     7.0    41.0    50.0    61.0   155.0    52.2    15.9
#                     bmi    14.2    23.9    27.4    31.6    73.4    28.4     6.6
#                 totChol    78.0   167.0   192.0   222.0   460.0   196.1    41.6
#                    trig    12.0    79.0   115.0   168.0  2549.0   139.0   104.1
#                     a1c     2.0     5.1     5.4     5.7    15.2     5.6     0.9
#                     ldl    23.0    92.0   114.0   140.0   344.0   118.0    36.6
#                   waist    59.1    85.6    96.4   107.1   178.2    97.6    16.3
#              creatinine     0.3     0.7     0.8     1.0    11.5     0.9     0.3
#                     sbp    78.0   110.0   118.7   130.0   224.0   121.6    17.0
#                     dbp    40.0    64.0    70.7    78.0   118.7    70.9    11.0
#   antiHypertensiveCount     0.0     0.0     0.0     1.0     7.0     0.5     0.8
#                           proportions
#                           -----------
#                    afib
#                       0   0.98
#                       1   0.02
#                     pvd
#                       0   0.97
#                       1   0.03
#          alcoholPerWeek
#                       0   0.16
#                       2   0.30
#                       3   0.54
#     anyPhysicalActivity
#                       0   0.23
#                       1   0.77
#           raceEthnicity
#                       1   0.09
#                       2   0.05
#                       3   0.69
#                       4   0.11
#                       5   0.06
#               education
#                       1   0.07
#                       2   0.13
#                       3   0.24
#                       4   0.31
#                       5   0.24
#                  gender
#                       1   0.48
#                       2   0.52
#           smokingStatus
#                       0   0.55
#                       1   0.23
#                       2   0.22
#                modality
#                      no   1.00
#                  statin
#                       0   0.83
#                       1   0.17
# 2013 Hypertension
#                           Printing a summary of risk factors and default treatments...
#                           min      0.25    med     0.75     max    mean     sd
#                           -----------------------------------------------------
#                     age    18.0    51.0    62.0    71.0    80.0    60.2    14.3
#                     hdl    11.0    41.0    49.0    60.0   173.0    51.6    15.6
#                     bmi    16.8    26.2    29.9    34.6    77.5    31.3     7.7
#                 totChol    82.0   155.0   183.0   209.0   813.0   185.5    43.9
#                    trig    14.0    74.0   112.0   159.0  2141.0   132.9   107.9
#                     a1c     3.5     5.4     5.7     6.2    17.5     6.0     1.2
#                     ldl     9.0    81.0   105.0   130.0   304.0   107.8    36.0
#                   waist    63.5    94.0   104.5   116.5   178.2   106.5    17.3
#              creatinine     0.3     0.8     0.9     1.1    17.4     1.0     0.7
#                     sbp    64.7   116.0   127.3   138.7   228.7   128.6    18.6
#                     dbp    40.0    62.0    70.7    77.3   116.7    70.0    11.4
#   antiHypertensiveCount     1.0     1.0     1.0     2.0     6.0     1.6     0.9
#                           proportions
#                           -----------
#                    afib
#                       0   0.94
#                       1   0.06
#                     pvd
#                       0   0.94
#                       1   0.06
#          alcoholPerWeek
#                       0   0.20
#                       2   0.36
#                       3   0.44
#     anyPhysicalActivity
#                       0   0.35
#                       1   0.65
#           raceEthnicity
#                       1   0.06
#                       2   0.03
#                       3   0.70
#                       4   0.15
#                       5   0.06
#               education
#                       1   0.05
#                       2   0.12
#                       3   0.25
#                       4   0.34
#                       5   0.25
#                  gender
#                       1   0.49
#                       2   0.51
#           smokingStatus
#                       0   0.51
#                       1   0.32
#                       2   0.16
#                modality
#                      no   1.00
#                  statin
#                       0   0.53
#                       1   0.47

# %%
#setting the path to None will display the figures (and not export them)
Validation.nhanes_over_time(nWorkers=5, path=None)
# Out:
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# VALIDATION OF VASCULAR RISK FACTORS OVER TIME
#                           self                                                    other
#                           -----------------------------------------------------   -----------------------------------------------------
#                           min      0.25    med     0.75     max    mean     sd     min     0.25    med     0.75     max    mean     sd
#                           -----------------------------------------------------   -----------------------------------------------------
#                     age    35.0    45.0    55.0    65.0   102.0    56.0    13.6    36.0    44.0    54.0    62.0    80.0    54.3    12.4
#                     sbp    81.7   120.2   128.5   138.3   269.0   130.0    14.9    79.0   112.0   124.0   136.7   222.7   126.6    19.8
#                     dbp    42.9    73.6    81.8    89.9   152.5    81.9    11.5    40.0    66.7    74.0    80.7   110.7    74.1    11.8
#                     a1c     4.0     5.5     5.7     6.1    10.6     5.8     0.6     4.3     5.4     5.7     6.1    14.3     6.0     1.1
#                     hdl     5.4    34.9    47.2    62.3   170.2    49.8    21.2    11.0    42.0    51.0    60.0   147.0    52.9    15.5
#                     ldl     8.1    94.4   115.0   133.3   291.1   112.9    30.4    18.0    94.0   118.0   142.0   264.0   119.6    38.2
#                    trig     9.0   103.7   148.1   196.7   449.9   153.4    69.3    18.0    74.0   106.0   155.0  1002.0   125.5    82.9
#                 totChol   102.0   180.7   192.5   203.7   303.8   192.0    17.7    76.0   171.0   194.0   221.0   354.0   197.2    42.4
#                     bmi    10.8    24.9    29.0    34.1    90.2    30.2     8.3    14.2    24.9    27.8    31.1    64.7    28.6     5.4
#                   waist    50.0    87.4    97.7   109.8   196.9    99.9    18.4    64.7    89.8    96.8   105.2   152.8    98.0    12.8
#              creatinine     0.1     0.5     0.7     0.9    13.3     0.7     0.5     0.2     0.7     0.8     0.9    11.5     0.8     0.4
#   antiHypertensiveCount     0.0     0.0     1.0     3.0    12.0     1.7     1.7     0.0     0.0     0.0     1.0     5.0     0.6     0.9
#                           self   other
#                           proportions
#                           -----------
#     anyPhysicalActivity
#                       0   0.35   0.28
#                       1   0.65   0.72
#          alcoholPerWeek
#                       0   0.07   0.12
#                       1   0.86   0.00
#                       2   0.07   0.40
#                    afib
#                       0   0.82   0.97
#                       1   0.18   0.03
#                     pvd
#                       0   0.97   0.97
#                       1   0.03   0.03
#           raceEthnicity
#                       1   0.07   0.26
#                       2   0.09   0.22
#                       3   0.67   0.17
#                       4   0.11   0.05
#                       5   0.05   0.29
#               education
#                       1   0.05   0.18
#                       2   0.15   0.09
#                       3   0.24   0.21
#                       4   0.32   0.20
#                       5   0.23   0.32
#                  gender
#                       1   0.48   0.48
#                       2   0.52   0.52
#           smokingStatus
#                       0   0.55   0.66
#                       1   0.20   0.25
#                       2   0.24   0.09
#                modality
#                      no   1.00   1.00
#                  statin
#                       0   0.70   0.71
#                       1   0.30   0.29
#
# VALIDATION OF CV EVENT INCIDENCE AND MORTALITY
# standardized rates (per 100,000)    all        black      white
#                             mi      300.7      265.5      319.4
#                         stroke      189.4      335.1      149.5
#                          death     1045.1     1219.9     1062.9
#                             cv      490.1      600.7      468.9
#                          noncv      974.7     1124.2      997.3
#                       dementia      336.6      686.9      288.8
#
# VALIDATION OF DEMENTIA INCIDENCE

# %%
# %%time
Validation.nhanes_treatment_effects(sampleSize=100000, nWorkers=4)
# Out:
# VALIDATION OF TREATMENT EFFECTS
#
# bpMedsAdded=1
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Trial is completed.
# 		simulation=0, strokeRR= 0.80    , miRR= 0.90
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Trial is completed.
# 		simulation=1, strokeRR= 0.83    , miRR= 0.88
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Trial is completed.
# 		simulation=2, strokeRR= 0.84    , miRR= 0.87
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Trial is completed.
# 		simulation=3, strokeRR= 0.78    , miRR= 0.81
#     average of 4 simulations: strokeRR= 0.81    , miRR= 0.86
#          sd of 4 simulations: strokeRR= 0.03    , miRR= 0.03
#
# bpMedsAdded=2
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Trial is completed.
# 		simulation=0, strokeRR= 0.66    , miRR= 0.74
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Trial is completed.
# 		simulation=1, strokeRR= 0.63    , miRR= 0.79
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Trial is completed.
# 		simulation=2, strokeRR= 0.64    , miRR= 0.75
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Trial is completed.
# 		simulation=3, strokeRR= 0.63    , miRR= 0.75
#     average of 4 simulations: strokeRR= 0.64    , miRR= 0.76
#          sd of 4 simulations: strokeRR= 0.01    , miRR= 0.02
#
# bpMedsAdded=3
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Trial is completed.
# 		simulation=0, strokeRR= 0.49    , miRR= 0.64
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Trial is completed.
# 		simulation=1, strokeRR= 0.43    , miRR= 0.67
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Trial is completed.
# 		simulation=2, strokeRR= 0.54    , miRR= 0.68
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Trial is completed.
# 		simulation=3, strokeRR= 0.46    , miRR= 0.60
#     average of 4 simulations: strokeRR= 0.48    , miRR= 0.65
#          sd of 4 simulations: strokeRR= 0.04    , miRR= 0.03
#
# bpMedsAdded=4
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Trial is completed.
# 		simulation=0, strokeRR= 0.38    , miRR= 0.56
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Trial is completed.
# 		simulation=1, strokeRR= 0.33    , miRR= 0.52
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Trial is completed.
# 		simulation=2, strokeRR= 0.36    , miRR= 0.55
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'Series.swapaxes' is deprecated and will be removed in a future version. Please use 'Series.transpose' instead.
#   return bound(*args, **kwds)
# Trial is completed.
# 		simulation=3, strokeRR= 0.37    , miRR= 0.65
#     average of 4 simulations: strokeRR= 0.36    , miRR= 0.57
#          sd of 4 simulations: strokeRR= 0.02    , miRR= 0.05
# CPU times: user 55min 4s, sys: 16min 2s, total: 1h 11min 7s
# Wall time: 2h 12min 10s
