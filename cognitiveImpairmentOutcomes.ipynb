# %%
#note: must use a microsim kernel or a kernel that can load all necessary python modules

# %%
import os
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
from pandarallel import pandarallel
import multiprocessing as mp

# %%
from microsim.bp_treatment_strategies import *

from microsim.outcome_model_repository import OutcomeModelRepository
from microsim.outcome_model_type import OutcomeModelType
from microsim.person import Person

from microsim.population import NHANESDirectSamplePopulation

from microsim.bp_treatment_strategies import SprintTreatment

from microsim.sim_settings import simSettings

from microsim.trials.trialset import TrialsetParallel, TrialsetSerial
from microsim.trials.trial_description import TrialDescription
from microsim.trials.logistic_regression_analysis import LogisticRegressionAnalysis
from microsim.trials.linear_regression_analysis import LinearRegressionAnalysis
from microsim.trials.outcome_assessor import OutcomeAssessor
from microsim.trials.attribute_outcome_assessor import AttributeOutcomeAssessor
from microsim.trials.attribute_outcome_assessor import AssessmentMethod
from microsim.trials.risk_filter import RiskFilter
from microsim.trials.trial_utils import get_analysis_name, randomizationSchema

# %%
#any microsim dir will work, just need to access the NHANES data
microsimDir = "/Users/deligkaris.1/OneDrive - The Ohio State University Wexner Medical Center/MICROSIM/CODE/microsim"
os.chdir(microsimDir)

# %%
#at the beginning turn on pandarallel if you are planning to use TrialsetSerial
pandarallel.initialize(verbose=1) #microsim by default now does not initialize pandarallel
simSettings.pandarallelFlag = True #with this flag all new population instances will be set to use pandarallel

# %%
#with pandarallel on these two steps are faster
pop = NHANESDirectSamplePopulation(10000, 1999)
#alive, df = pop.advance_vectorized(30)

# %%
for x in range(0,8):
    print(pop._people.iloc[x]._gcp, OutcomeAssessor([OutcomeAssessor.CI]).get_outcome(pop._people.iloc[x]))

# %%
pop._people.iloc[7]._gcp, OutcomeAssessor([OutcomeAssessor.CI]).get_outcome(pop._people.iloc[7])

# %%
anyEvent2 = LogisticRegressionAnalysis(OutcomeAssessor([OutcomeAssessor.DEATH, OutcomeType.STROKE, OutcomeType.MI, OutcomeType.DEMENTIA, OutcomeAssessor.CI]))
cogEvent = LogisticRegressionAnalysis(OutcomeAssessor([OutcomeAssessor.CI,OutcomeType.DEMENTIA]))
vascularEventOrDeath = LogisticRegressionAnalysis(OutcomeAssessor([OutcomeAssessor.DEATH, OutcomeType.STROKE, OutcomeType.MI]))
anyEvent = LogisticRegressionAnalysis(OutcomeAssessor([OutcomeAssessor.DEATH, OutcomeType.STROKE, OutcomeType.MI, OutcomeType.DEMENTIA]))
death = LogisticRegressionAnalysis(OutcomeAssessor([OutcomeAssessor.DEATH]))
qalys = LinearRegressionAnalysis(AttributeOutcomeAssessor("_qalys", AssessmentMethod.SUM))
meanGCP = LinearRegressionAnalysis(AttributeOutcomeAssessor("_gcp", AssessmentMethod.MEAN))
lastGCP = LinearRegressionAnalysis(AttributeOutcomeAssessor("_gcp", AssessmentMethod.LAST))

# %%
#we will later define how many processes to launch, this is just for validation
#and so that we do not set the number of processes to a number greater than the number of available cores
#print("code has access to cores ",len(os.sched_getaffinity(0)))

# %%
#these are usually set from the input file, but to make things easier here 
#just set them on the notebook (which means no script will test for their meaningfulness)
inputSampleSizes = [1000,2000,5000] #for quick tests
#inputSampleSizes = [100, 200, 500, 1000, 5000, 10000, 15000, 20000]
inputDurations = [1,2] #for quick tests
#inputDurations = [3,5,10,15,20]
#inputDemThresholds = [2.4845839854531493e-08, 0.00018576417292080007, 0.0012917270937081809, 0.005870510161620921, 0.025739443157677927]
#inputCvThresholds = [1.167603052003119e-06, 0.0008193743487641601, 0.0026191105926681, 0.006091251406939853, 0.0132184645579298]
#inputDemThresholds = [2.4845839854531493e-08,0.00018576417292080007] #for quick tests
#inputCvThresholds = [1.167603052003119e-06,0.0008193743487641601] #for quick tests
inputDemThresholds = [2.4845839854531493e-08] #for quick tests
inputCvThresholds = [1.167603052003119e-06] #for quick tests
inputTrialsetSize = 3
inputProcesses = 3

# %%
#if you try running a TrialsetParallel instance with pandarallel on, you will get an exception
#but these could be included in the TrialsetParallel.run() method
simSettings.pandarallelFlag = False #any new population instance will have pandarallel off 
pop.use_pandarallel(False) #for mp to pickle this instance that used pandarallel, must change its attributes

# %%
# %%time
#a drawback of including these thresholds outside of the trialset instances is that these cannot be parallelized
#so in every iteration, I have to wait until all trials of the trialset are done in order to proceed to the next
#iteration/trialset (=time lost)
#the more thresholds I have, the greater the time lost 
#but it is relative to have many trials the set has and how many cores I am using
results = None
for dem in inputDemThresholds:
    for cv in inputCvThresholds:
            myRiskFilter = RiskFilter({OutcomeModelType.DEMENTIA : dem , OutcomeModelType.CARDIOVASCULAR : cv})
            #this trial description will be the same for all trials in the trial set
            desc = TrialDescription(sampleSizes= inputSampleSizes,
                                                durations = inputDurations,
                                                inclusionFilter=myRiskFilter.exceedsThresholds,
                                                exclusionFilter=None,
                                                analyses=[anyEvent2,
                                                          cogEvent,
                                                        death,
                                                        anyEvent,
                                                        vascularEventOrDeath,
                                                        qalys,
                                                        meanGCP,
                                                        lastGCP],
                                                treatment=SprintTreatment(),
                                                randomizationSchema=randomizationSchema)
            #create the set
            trialset = TrialsetParallel(desc,
                                        pop,
                                        inputTrialsetSize,
                                        inputProcesses, #an extra argument for TrialsetParallel
                                        additionalLabels=myRiskFilter._outcomeRiskThresholds)
            #trialset = TrialsetSerial(desc,
            #                          pop,
            #                          inputTrialsetSize,
            #                          additionalLabels=myRiskFilter._outcomeRiskThresholds)
            if __name__ ==  '__main__': #launching processes with multiprocesses requires this
                if results is None:
                    results = trialset.run()
                else:
                    results = pd.concat([results,trialset.run()]).reset_index(drop=True)
# Out:
# starting trial 0 now
# starting trial 1 now
# starting trial 2 now
# /Users/deligkaris.1/Library/CloudStorage/OneDrive-TheOhioStateUniversityWexnerMedicalCenter/MICROSIM/CODE/microsim/microsim/population.py:342: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totalBPMedsAddedCapped.loc[totalBPMedsAddedCapped >= BaseTreatmentStrategy.MAX_BP_MEDS] = BaseTreatmentStrategy.MAX_BP_MEDS
# /Users/deligkaris.1/Library/CloudStorage/OneDrive-TheOhioStateUniversityWexnerMedicalCenter/MICROSIM/CODE/microsim/microsim/population.py:342: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totalBPMedsAddedCapped.loc[totalBPMedsAddedCapped >= BaseTreatmentStrategy.MAX_BP_MEDS] = BaseTreatmentStrategy.MAX_BP_MEDS
# /Users/deligkaris.1/Library/CloudStorage/OneDrive-TheOhioStateUniversityWexnerMedicalCenter/MICROSIM/CODE/microsim/microsim/population.py:342: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   totalBPMedsAddedCapped.loc[totalBPMedsAddedCapped >= BaseTreatmentStrategy.MAX_BP_MEDS] = BaseTreatmentStrategy.MAX_BP_MEDS
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# ...
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# ending trial 0 now
# ending trial 1 now
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/statsmodels/base/optimizer.py:17: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol. The list of unsupported keyword arguments passed include: method_kwargs. After release 0.14, this will raise.
#   warnings.warn(
# ending trial 2 now
# CPU times: user 316 ms, sys: 70.4 ms, total: 387 ms
# Wall time: 57.8 s

# %%
results
# Out:
#               reg            se        pvalue  absEffectSize  duration  \
# 0   -2.726118e-01  2.236793e-01  2.229346e-01      -0.022000         1
# 1   -1.239934e-01  1.502887e-01  4.093516e-01      -0.011000         1
# 2   -1.602031e-03  9.413235e-02  9.864215e-01      -0.000145         1
# 3   -1.287121e-01  2.271430e-01  5.709474e-01      -0.010000         2
# 4   -9.356359e-02  1.635931e-01  5.673704e-01      -0.007000         2
# 5   -1.002041e-01  1.027236e-01  3.293255e-01      -0.007616         2
# 6   -3.007542e-01  2.251722e-01  1.816595e-01      -0.024000         1
# 7   -1.142585e-01  1.512891e-01  4.501091e-01      -0.010000         1
# 8    1.096656e-02  9.505659e-02  9.081529e-01       0.000971         1
# 9   -7.886376e-02  2.293859e-01  7.309938e-01      -0.006000         2
# 10  -1.113310e-01  1.669667e-01  5.049090e-01      -0.008000         2
# 11  -5.756210e-02  1.050819e-01  5.838407e-01      -0.004176         2
# 12   1.458500e+01  1.467770e+03  9.920717e-01       0.002000         1
# 13  -6.941487e-01  1.225562e+00  5.711273e-01      -0.001000         1
# 14  -1.850704e-01  6.714177e-01  7.828236e-01      -0.000331         1
# 15  -2.557511e+01  3.573799e+05  9.999429e-01      -0.002000         2
# 16   2.886856e-01  7.650754e-01  7.059287e-01       0.001000         2
# 17  -7.374503e-01  4.943613e-01  1.357717e-01      -0.002655         2
# 18   1.458500e+01  1.467770e+03  9.920717e-01       0.002000         1
# 19  -6.941487e-01  1.225562e+00  5.711273e-01      -0.001000         1
# 20  -5.223294e-01  6.274227e-01  4.051267e-01      -0.001116         1
# 21  -2.627027e+01  3.573808e+05  9.999413e-01      -0.004000         2
# 22   2.886856e-01  7.650754e-01  7.059287e-01       0.001000         2
# 23  -9.462738e-01  4.795523e-01  4.846777e-02      -0.003832         2
# 24   1.458500e+01  1.467770e+03  9.920717e-01       0.002000         1
# 25  -6.941487e-01  1.225562e+00  5.711273e-01      -0.001000         1
# 26  -5.223294e-01  6.274227e-01  4.051267e-01      -0.001116         1
# 27  -2.627027e+01  3.573808e+05  9.999413e-01      -0.004000         2
# 28   2.886856e-01  7.650754e-01  7.059287e-01       0.001000         2
# 29  -9.462738e-01  4.795523e-01  4.846777e-02      -0.003832         2
# 30   4.163336e-16  1.988016e-17  5.228292e-81       0.000000         1
# 31   5.551115e-17  1.987021e-17  5.260792e-03       0.000000         1
# 32   7.849294e-04  5.656808e-04  1.653257e-01       0.000785         1
# 33   2.000000e-03  2.000000e-03  3.175529e-01       0.002000         2
# 34  -1.000000e-03  1.731473e-03  5.636378e-01      -0.001000         2
# 35   1.900861e-03  1.440647e-03  1.870795e-01       0.001901         2
# 36   1.600000e-01  2.208927e-01  4.690307e-01       0.160000         1
# 37   5.200000e-02  1.558370e-01  7.386545e-01       0.052000         1
# 38  -6.798666e-02  9.889940e-02  4.918421e-01      -0.067987         1
# 39   3.800000e-02  2.122002e-01  8.579142e-01       0.038000         2
# 40   1.190000e-01  1.454330e-01  4.133141e-01       0.119000         2
# 41  -2.459787e-02  9.265796e-02  7.906587e-01      -0.024598         2
# 42   3.080000e-01  4.401142e-01  4.842039e-01       0.308000         1
# 43   1.500000e-01  3.097030e-01  6.282012e-01       0.150000         1
# 44  -1.075648e-01  1.967976e-01  5.846947e-01      -0.107565         1
# 45   7.940000e-01  4.418706e-01  7.265281e-02       0.794000         2
# 46   6.650000e-01  3.075516e-01  3.071810e-02       0.665000         2
# 47   5.619223e-02  1.960383e-01  7.744005e-01       0.056192         2
# 48   1.289059e-01  2.074957e-01  5.344376e-01       0.012000         1
# 49  -2.442094e-02  1.562779e-01  8.758232e-01      -0.002000         1
# 50   5.848551e-02  9.468822e-02  5.367968e-01       0.005223         1
# 51   2.451225e-01  2.222524e-01  2.700701e-01       0.020000         2
# 52   1.439299e-01  1.619838e-01  3.742478e-01       0.011000         2
# 53   1.358056e-01  1.006227e-01  1.771277e-01       0.010766         2
# 54   1.311463e-01  2.092998e-01  5.309245e-01       0.012000         1
# 55   2.649958e-15  1.621031e-01  1.000000e+00       0.000000         1
# 56   5.300655e-02  9.661731e-02  5.832637e-01       0.004546         1
# 57   2.373533e-01  2.304965e-01  3.031282e-01       0.018000         2
# 58   1.260160e-01  1.675166e-01  4.518950e-01       0.009000         2
# 59   1.175464e-01  1.048402e-01  2.622042e-01       0.008578         2
# 60  -2.557511e+01  3.573799e+05  9.999429e-01      -0.002000         1
# 61  -5.626324e-01  6.283854e-01  3.705936e-01      -0.003000         1
# 62  -2.809173e-02  5.008021e-01  9.552673e-01      -0.000090         1
# 63  -4.074752e-01  9.150702e-01  6.561074e-01      -0.002000         2
# 64   4.074752e-01  6.470523e-01  5.288643e-01       0.002000         2
# 65   1.671872e-01  3.620183e-01  6.442106e-01       0.001027         2
# 66  -8.348948e-16  1.415630e+00  1.000000e+00       0.000000         1
# 67  -2.896962e-01  5.419232e-01  5.929469e-01      -0.002000         1
# 68   1.549996e-01  4.291119e-01  7.179422e-01       0.000677         1
# 69   2.896962e-01  7.663952e-01  7.054318e-01       0.002000         2
# 70   3.384843e-01  5.872557e-01  5.643562e-01       0.002000         2
# 71   3.375060e-01  3.267793e-01  3.016855e-01       0.002582         2
# 72  -8.348948e-16  1.415630e+00  1.000000e+00       0.000000         1
# 73  -2.896962e-01  5.419232e-01  5.929469e-01      -0.002000         1
# 74   1.549996e-01  4.291119e-01  7.179422e-01       0.000677         1
# 75   2.896962e-01  7.663952e-01  7.054318e-01       0.002000         2
# 76   3.384843e-01  5.872557e-01  5.643562e-01       0.002000         2
# 77   3.375060e-01  3.267793e-01  3.016855e-01       0.002582         2
# 78  -2.000000e-03  2.000000e-03  3.175529e-01      -0.002000         1
# 79   5.551115e-17  1.998999e-03  1.000000e+00       0.000000         1
# 80  -7.553480e-04  1.130752e-03  5.041612e-01      -0.000755         1
# 81  -2.000000e-03  5.989302e-03  7.385035e-01      -0.002000         2
# 82   1.000000e-03  2.234277e-03  6.545105e-01       0.001000         2
# 83  -1.849162e-03  2.222371e-03  4.054106e-01      -0.001849         2
# 84  -4.500000e-01  2.257249e-01  4.647009e-02      -0.450000         1
# 85  -1.120000e-01  1.520763e-01  4.615298e-01      -0.112000         1
# 86  -1.165364e-01  9.922239e-02  2.402518e-01      -0.116536         1
# 87  -2.320000e-01  2.138955e-01  2.783422e-01      -0.232000         2
# 88  -1.650000e-01  1.482405e-01  2.658181e-01      -0.165000         2
# 89  -1.404939e-01  9.445467e-02  1.369665e-01      -0.140494         2
# 90  -9.420000e-01  4.512752e-01  3.710356e-02      -0.942000         1
# 91  -2.390000e-01  3.044718e-01  4.325666e-01      -0.239000         1
# 92  -2.522878e-01  1.981835e-01  2.030768e-01      -0.252288         1
# 93  -5.880000e-01  4.478968e-01  1.895514e-01      -0.588000         2
# 94  -3.270000e-01  3.105847e-01  2.925358e-01      -0.327000         2
# 95  -1.766218e-01  1.988435e-01  3.744516e-01      -0.176622         2
# 96  -2.093178e-02  2.046112e-01  9.185184e-01      -0.002000         1
# 97  -2.569329e-01  1.534568e-01  9.407149e-02      -0.022000         1
# 98  -2.968608e-02  9.533252e-02  7.555003e-01      -0.002614         1
# 99   6.145950e-02  2.479731e-01  8.042524e-01       0.004000         2
# 100  1.168529e-01  1.710734e-01  4.945705e-01       0.008000         2
# 101 -3.728906e-03  1.058530e-01  9.718986e-01      -0.000266         2
# 102  9.165860e-16  2.071855e-01  1.000000e+00       0.000000         1
# 103 -2.859736e-01  1.551610e-01  6.531789e-02      -0.024000         1
# 104 -2.187265e-02  9.657355e-02  8.208227e-01      -0.001877         1
# 105  2.684089e-01  2.603188e-01  3.025045e-01       0.016000         2
# 106  1.538536e-01  1.756945e-01  3.811994e-01       0.010000         2
# 107  4.214041e-02  1.095667e-01  7.005267e-01       0.002809         2
# 108 -6.951532e-01  1.226382e+00  5.708279e-01      -0.002000         1
# 109  1.100616e+00  1.155568e+00  3.408708e-01       0.002000         1
# 110 -3.148194e-01  5.862245e-01  5.912477e-01      -0.000746         1
# 111 -2.696744e+01  3.573813e+05  9.999398e-01      -0.008000         2
# 112 -6.951532e-01  8.671828e-01  4.227714e-01      -0.002000         2
# 113 -5.395267e-01  4.441083e-01  2.244218e-01      -0.002302         2
# 114 -6.951532e-01  1.226382e+00  5.708279e-01      -0.002000         1
# 115  1.100616e+00  1.155568e+00  3.408708e-01       0.002000         1
# 116 -2.660206e-01  5.408040e-01  6.227913e-01      -0.000737         1
# 117 -2.737695e+01  3.573814e+05  9.999389e-01      -0.012000         2
# 118 -5.128337e-01  7.316703e-01  4.833603e-01      -0.002000         2
# 119 -5.684779e-01  3.954240e-01  1.505358e-01      -0.003075         2
# 120 -6.951532e-01  1.226382e+00  5.708279e-01      -0.002000         1
# 121  1.100616e+00  1.155568e+00  3.408708e-01       0.002000         1
# 122 -2.660206e-01  5.408040e-01  6.227913e-01      -0.000737         1
# 123 -2.737695e+01  3.573814e+05  9.999389e-01      -0.012000         2
# 124 -5.128337e-01  7.316703e-01  4.833603e-01      -0.002000         2
# 125 -5.684779e-01  3.954240e-01  1.505358e-01      -0.003075         2
# 126  4.163336e-16  1.988016e-17  5.228292e-81       0.000000         1
# 127  5.551115e-17  1.987021e-17  5.260792e-03       0.000000         1
# 128 -8.961124e-06  5.657209e-04  9.873625e-01      -0.000009         1
# 129  8.000000e-03  3.987958e-03  4.512154e-02       0.008000         2
# 130  2.000000e-03  2.446627e-03  4.137678e-01       0.002000         2
# 131  1.115020e-03  1.740630e-03  5.218222e-01       0.001115         2
# 132  1.700000e-01  2.171501e-01  4.338900e-01       0.170000         1
# 133  2.380000e-01  1.551952e-01  1.252982e-01       0.238000         1
# 134  3.140106e-02  9.844233e-02  7.497556e-01       0.031401         1
# 135  4.400000e-01  1.989723e-01  2.723669e-02       0.440000         2
# 136  2.120000e-01  1.438347e-01  1.406621e-01       0.212000         2
# 137  1.009931e-01  9.214838e-02  2.731386e-01       0.100993         2
# 138  3.880000e-01  4.345774e-01  3.721680e-01       0.388000         1
# 139  4.760000e-01  3.101339e-01  1.249861e-01       0.476000         1
# 140  6.335643e-02  1.969240e-01  7.476705e-01       0.063356         1
# 141  5.040000e-01  4.319165e-01  2.435327e-01       0.504000         2
# 142  2.640000e-01  3.108958e-01  3.958945e-01       0.264000         2
# 143  2.890193e-01  1.948672e-01  1.380948e-01       0.289019         2
#
#      sampleSize                       outcome  \
# 0          1000  death-stroke-mi-dementia-ci-
# 1          2000  death-stroke-mi-dementia-ci-
# 2          5000  death-stroke-mi-dementia-ci-
# 3          1000  death-stroke-mi-dementia-ci-
# 4          2000  death-stroke-mi-dementia-ci-
# 5          5000  death-stroke-mi-dementia-ci-
# 6          1000                  ci-dementia-
# 7          2000                  ci-dementia-
# 8          5000                  ci-dementia-
# 9          1000                  ci-dementia-
# 10         2000                  ci-dementia-
# 11         5000                  ci-dementia-
# 12         1000                        death-
# 13         2000                        death-
# 14         5000                        death-
# 15         1000                        death-
# 16         2000                        death-
# 17         5000                        death-
# 18         1000     death-stroke-mi-dementia-
# 19         2000     death-stroke-mi-dementia-
# 20         5000     death-stroke-mi-dementia-
# 21         1000     death-stroke-mi-dementia-
# 22         2000     death-stroke-mi-dementia-
# 23         5000     death-stroke-mi-dementia-
# 24         1000              death-stroke-mi-
# 25         2000              death-stroke-mi-
# 26         5000              death-stroke-mi-
# 27         1000              death-stroke-mi-
# 28         2000              death-stroke-mi-
# 29         5000              death-stroke-mi-
# 30         1000                    _qalys-sum
# 31         2000                    _qalys-sum
# 32         5000                    _qalys-sum
# 33         1000                    _qalys-sum
# 34         2000                    _qalys-sum
# 35         5000                    _qalys-sum
# 36         1000                     _gcp-mean
# 37         2000                     _gcp-mean
# 38         5000                     _gcp-mean
# 39         1000                     _gcp-mean
# 40         2000                     _gcp-mean
# 41         5000                     _gcp-mean
# 42         1000                     _gcp-last
# 43         2000                     _gcp-last
# 44         5000                     _gcp-last
# 45         1000                     _gcp-last
# 46         2000                     _gcp-last
# 47         5000                     _gcp-last
# 48         1000  death-stroke-mi-dementia-ci-
# 49         2000  death-stroke-mi-dementia-ci-
# 50         5000  death-stroke-mi-dementia-ci-
# 51         1000  death-stroke-mi-dementia-ci-
# 52         2000  death-stroke-mi-dementia-ci-
# 53         5000  death-stroke-mi-dementia-ci-
# 54         1000                  ci-dementia-
# 55         2000                  ci-dementia-
# 56         5000                  ci-dementia-
# 57         1000                  ci-dementia-
# 58         2000                  ci-dementia-
# 59         5000                  ci-dementia-
# 60         1000                        death-
# 61         2000                        death-
# 62         5000                        death-
# 63         1000                        death-
# 64         2000                        death-
# 65         5000                        death-
# 66         1000     death-stroke-mi-dementia-
# 67         2000     death-stroke-mi-dementia-
# 68         5000     death-stroke-mi-dementia-
# 69         1000     death-stroke-mi-dementia-
# 70         2000     death-stroke-mi-dementia-
# 71         5000     death-stroke-mi-dementia-
# 72         1000              death-stroke-mi-
# 73         2000              death-stroke-mi-
# 74         5000              death-stroke-mi-
# 75         1000              death-stroke-mi-
# 76         2000              death-stroke-mi-
# 77         5000              death-stroke-mi-
# 78         1000                    _qalys-sum
# 79         2000                    _qalys-sum
# 80         5000                    _qalys-sum
# 81         1000                    _qalys-sum
# 82         2000                    _qalys-sum
# 83         5000                    _qalys-sum
# 84         1000                     _gcp-mean
# 85         2000                     _gcp-mean
# 86         5000                     _gcp-mean
# 87         1000                     _gcp-mean
# 88         2000                     _gcp-mean
# 89         5000                     _gcp-mean
# 90         1000                     _gcp-last
# 91         2000                     _gcp-last
# 92         5000                     _gcp-last
# 93         1000                     _gcp-last
# 94         2000                     _gcp-last
# 95         5000                     _gcp-last
# 96         1000  death-stroke-mi-dementia-ci-
# 97         2000  death-stroke-mi-dementia-ci-
# 98         5000  death-stroke-mi-dementia-ci-
# 99         1000  death-stroke-mi-dementia-ci-
# 100        2000  death-stroke-mi-dementia-ci-
# 101        5000  death-stroke-mi-dementia-ci-
# 102        1000                  ci-dementia-
# 103        2000                  ci-dementia-
# 104        5000                  ci-dementia-
# 105        1000                  ci-dementia-
# 106        2000                  ci-dementia-
# 107        5000                  ci-dementia-
# 108        1000                        death-
# 109        2000                        death-
# 110        5000                        death-
# 111        1000                        death-
# 112        2000                        death-
# 113        5000                        death-
# 114        1000     death-stroke-mi-dementia-
# 115        2000     death-stroke-mi-dementia-
# 116        5000     death-stroke-mi-dementia-
# 117        1000     death-stroke-mi-dementia-
# 118        2000     death-stroke-mi-dementia-
# 119        5000     death-stroke-mi-dementia-
# 120        1000              death-stroke-mi-
# 121        2000              death-stroke-mi-
# 122        5000              death-stroke-mi-
# 123        1000              death-stroke-mi-
# 124        2000              death-stroke-mi-
# 125        5000              death-stroke-mi-
# 126        1000                    _qalys-sum
# 127        2000                    _qalys-sum
# 128        5000                    _qalys-sum
# 129        1000                    _qalys-sum
# 130        2000                    _qalys-sum
# 131        5000                    _qalys-sum
# 132        1000                     _gcp-mean
# 133        2000                     _gcp-mean
# 134        5000                     _gcp-mean
# 135        1000                     _gcp-mean
# 136        2000                     _gcp-mean
# 137        5000                     _gcp-mean
# 138        1000                     _gcp-last
# 139        2000                     _gcp-last
# 140        5000                     _gcp-last
# 141        1000                     _gcp-last
# 142        2000                     _gcp-last
# 143        5000                     _gcp-last
#
#                                             analysis  \
# 0    logisticRegression-death-stroke-mi-dementia-ci-
# 1    logisticRegression-death-stroke-mi-dementia-ci-
# 2    logisticRegression-death-stroke-mi-dementia-ci-
# 3    logisticRegression-death-stroke-mi-dementia-ci-
# 4    logisticRegression-death-stroke-mi-dementia-ci-
# 5    logisticRegression-death-stroke-mi-dementia-ci-
# 6                    logisticRegression-ci-dementia-
# 7                    logisticRegression-ci-dementia-
# 8                    logisticRegression-ci-dementia-
# 9                    logisticRegression-ci-dementia-
# 10                   logisticRegression-ci-dementia-
# 11                   logisticRegression-ci-dementia-
# 12                         logisticRegression-death-
# 13                         logisticRegression-death-
# 14                         logisticRegression-death-
# 15                         logisticRegression-death-
# 16                         logisticRegression-death-
# 17                         logisticRegression-death-
# 18      logisticRegression-death-stroke-mi-dementia-
# 19      logisticRegression-death-stroke-mi-dementia-
# 20      logisticRegression-death-stroke-mi-dementia-
# 21      logisticRegression-death-stroke-mi-dementia-
# 22      logisticRegression-death-stroke-mi-dementia-
# 23      logisticRegression-death-stroke-mi-dementia-
# 24               logisticRegression-death-stroke-mi-
# 25               logisticRegression-death-stroke-mi-
# 26               logisticRegression-death-stroke-mi-
# 27               logisticRegression-death-stroke-mi-
# 28               logisticRegression-death-stroke-mi-
# 29               logisticRegression-death-stroke-mi-
# 30                       linearRegression-_qalys-sum
# 31                       linearRegression-_qalys-sum
# 32                       linearRegression-_qalys-sum
# 33                       linearRegression-_qalys-sum
# 34                       linearRegression-_qalys-sum
# 35                       linearRegression-_qalys-sum
# 36                        linearRegression-_gcp-mean
# 37                        linearRegression-_gcp-mean
# 38                        linearRegression-_gcp-mean
# 39                        linearRegression-_gcp-mean
# 40                        linearRegression-_gcp-mean
# 41                        linearRegression-_gcp-mean
# 42                        linearRegression-_gcp-last
# 43                        linearRegression-_gcp-last
# 44                        linearRegression-_gcp-last
# 45                        linearRegression-_gcp-last
# 46                        linearRegression-_gcp-last
# 47                        linearRegression-_gcp-last
# 48   logisticRegression-death-stroke-mi-dementia-ci-
# 49   logisticRegression-death-stroke-mi-dementia-ci-
# 50   logisticRegression-death-stroke-mi-dementia-ci-
# 51   logisticRegression-death-stroke-mi-dementia-ci-
# 52   logisticRegression-death-stroke-mi-dementia-ci-
# 53   logisticRegression-death-stroke-mi-dementia-ci-
# 54                   logisticRegression-ci-dementia-
# 55                   logisticRegression-ci-dementia-
# 56                   logisticRegression-ci-dementia-
# 57                   logisticRegression-ci-dementia-
# 58                   logisticRegression-ci-dementia-
# 59                   logisticRegression-ci-dementia-
# 60                         logisticRegression-death-
# 61                         logisticRegression-death-
# 62                         logisticRegression-death-
# 63                         logisticRegression-death-
# 64                         logisticRegression-death-
# 65                         logisticRegression-death-
# 66      logisticRegression-death-stroke-mi-dementia-
# 67      logisticRegression-death-stroke-mi-dementia-
# 68      logisticRegression-death-stroke-mi-dementia-
# 69      logisticRegression-death-stroke-mi-dementia-
# 70      logisticRegression-death-stroke-mi-dementia-
# 71      logisticRegression-death-stroke-mi-dementia-
# 72               logisticRegression-death-stroke-mi-
# 73               logisticRegression-death-stroke-mi-
# 74               logisticRegression-death-stroke-mi-
# 75               logisticRegression-death-stroke-mi-
# 76               logisticRegression-death-stroke-mi-
# 77               logisticRegression-death-stroke-mi-
# 78                       linearRegression-_qalys-sum
# 79                       linearRegression-_qalys-sum
# 80                       linearRegression-_qalys-sum
# 81                       linearRegression-_qalys-sum
# 82                       linearRegression-_qalys-sum
# 83                       linearRegression-_qalys-sum
# 84                        linearRegression-_gcp-mean
# 85                        linearRegression-_gcp-mean
# 86                        linearRegression-_gcp-mean
# 87                        linearRegression-_gcp-mean
# 88                        linearRegression-_gcp-mean
# 89                        linearRegression-_gcp-mean
# 90                        linearRegression-_gcp-last
# 91                        linearRegression-_gcp-last
# 92                        linearRegression-_gcp-last
# 93                        linearRegression-_gcp-last
# 94                        linearRegression-_gcp-last
# 95                        linearRegression-_gcp-last
# 96   logisticRegression-death-stroke-mi-dementia-ci-
# 97   logisticRegression-death-stroke-mi-dementia-ci-
# 98   logisticRegression-death-stroke-mi-dementia-ci-
# 99   logisticRegression-death-stroke-mi-dementia-ci-
# 100  logisticRegression-death-stroke-mi-dementia-ci-
# 101  logisticRegression-death-stroke-mi-dementia-ci-
# 102                  logisticRegression-ci-dementia-
# 103                  logisticRegression-ci-dementia-
# 104                  logisticRegression-ci-dementia-
# 105                  logisticRegression-ci-dementia-
# 106                  logisticRegression-ci-dementia-
# 107                  logisticRegression-ci-dementia-
# 108                        logisticRegression-death-
# 109                        logisticRegression-death-
# 110                        logisticRegression-death-
# 111                        logisticRegression-death-
# 112                        logisticRegression-death-
# 113                        logisticRegression-death-
# 114     logisticRegression-death-stroke-mi-dementia-
# 115     logisticRegression-death-stroke-mi-dementia-
# 116     logisticRegression-death-stroke-mi-dementia-
# 117     logisticRegression-death-stroke-mi-dementia-
# 118     logisticRegression-death-stroke-mi-dementia-
# 119     logisticRegression-death-stroke-mi-dementia-
# 120              logisticRegression-death-stroke-mi-
# 121              logisticRegression-death-stroke-mi-
# 122              logisticRegression-death-stroke-mi-
# 123              logisticRegression-death-stroke-mi-
# 124              logisticRegression-death-stroke-mi-
# 125              logisticRegression-death-stroke-mi-
# 126                      linearRegression-_qalys-sum
# 127                      linearRegression-_qalys-sum
# 128                      linearRegression-_qalys-sum
# 129                      linearRegression-_qalys-sum
# 130                      linearRegression-_qalys-sum
# 131                      linearRegression-_qalys-sum
# 132                       linearRegression-_gcp-mean
# 133                       linearRegression-_gcp-mean
# 134                       linearRegression-_gcp-mean
# 135                       linearRegression-_gcp-mean
# 136                       linearRegression-_gcp-mean
# 137                       linearRegression-_gcp-mean
# 138                       linearRegression-_gcp-last
# 139                       linearRegression-_gcp-last
# 140                       linearRegression-_gcp-last
# 141                       linearRegression-_gcp-last
# 142                       linearRegression-_gcp-last
# 143                       linearRegression-_gcp-last
#
#      OutcomeModelType.DEMENTIA  OutcomeModelType.CARDIOVASCULAR
# 0                 2.484584e-08                         0.000001
# 1                 2.484584e-08                         0.000001
# 2                 2.484584e-08                         0.000001
# 3                 2.484584e-08                         0.000001
# 4                 2.484584e-08                         0.000001
# 5                 2.484584e-08                         0.000001
# 6                 2.484584e-08                         0.000001
# 7                 2.484584e-08                         0.000001
# 8                 2.484584e-08                         0.000001
# 9                 2.484584e-08                         0.000001
# 10                2.484584e-08                         0.000001
# 11                2.484584e-08                         0.000001
# 12                2.484584e-08                         0.000001
# 13                2.484584e-08                         0.000001
# 14                2.484584e-08                         0.000001
# 15                2.484584e-08                         0.000001
# 16                2.484584e-08                         0.000001
# 17                2.484584e-08                         0.000001
# 18                2.484584e-08                         0.000001
# 19                2.484584e-08                         0.000001
# 20                2.484584e-08                         0.000001
# 21                2.484584e-08                         0.000001
# 22                2.484584e-08                         0.000001
# 23                2.484584e-08                         0.000001
# 24                2.484584e-08                         0.000001
# 25                2.484584e-08                         0.000001
# 26                2.484584e-08                         0.000001
# 27                2.484584e-08                         0.000001
# 28                2.484584e-08                         0.000001
# 29                2.484584e-08                         0.000001
# 30                2.484584e-08                         0.000001
# 31                2.484584e-08                         0.000001
# 32                2.484584e-08                         0.000001
# 33                2.484584e-08                         0.000001
# 34                2.484584e-08                         0.000001
# 35                2.484584e-08                         0.000001
# 36                2.484584e-08                         0.000001
# 37                2.484584e-08                         0.000001
# 38                2.484584e-08                         0.000001
# 39                2.484584e-08                         0.000001
# 40                2.484584e-08                         0.000001
# 41                2.484584e-08                         0.000001
# 42                2.484584e-08                         0.000001
# 43                2.484584e-08                         0.000001
# 44                2.484584e-08                         0.000001
# 45                2.484584e-08                         0.000001
# 46                2.484584e-08                         0.000001
# 47                2.484584e-08                         0.000001
# 48                2.484584e-08                         0.000001
# 49                2.484584e-08                         0.000001
# 50                2.484584e-08                         0.000001
# 51                2.484584e-08                         0.000001
# 52                2.484584e-08                         0.000001
# 53                2.484584e-08                         0.000001
# 54                2.484584e-08                         0.000001
# 55                2.484584e-08                         0.000001
# 56                2.484584e-08                         0.000001
# 57                2.484584e-08                         0.000001
# 58                2.484584e-08                         0.000001
# 59                2.484584e-08                         0.000001
# 60                2.484584e-08                         0.000001
# 61                2.484584e-08                         0.000001
# 62                2.484584e-08                         0.000001
# 63                2.484584e-08                         0.000001
# 64                2.484584e-08                         0.000001
# 65                2.484584e-08                         0.000001
# 66                2.484584e-08                         0.000001
# 67                2.484584e-08                         0.000001
# 68                2.484584e-08                         0.000001
# 69                2.484584e-08                         0.000001
# 70                2.484584e-08                         0.000001
# 71                2.484584e-08                         0.000001
# 72                2.484584e-08                         0.000001
# 73                2.484584e-08                         0.000001
# 74                2.484584e-08                         0.000001
# 75                2.484584e-08                         0.000001
# 76                2.484584e-08                         0.000001
# 77                2.484584e-08                         0.000001
# 78                2.484584e-08                         0.000001
# 79                2.484584e-08                         0.000001
# 80                2.484584e-08                         0.000001
# 81                2.484584e-08                         0.000001
# 82                2.484584e-08                         0.000001
# 83                2.484584e-08                         0.000001
# 84                2.484584e-08                         0.000001
# 85                2.484584e-08                         0.000001
# 86                2.484584e-08                         0.000001
# 87                2.484584e-08                         0.000001
# 88                2.484584e-08                         0.000001
# 89                2.484584e-08                         0.000001
# 90                2.484584e-08                         0.000001
# 91                2.484584e-08                         0.000001
# 92                2.484584e-08                         0.000001
# 93                2.484584e-08                         0.000001
# 94                2.484584e-08                         0.000001
# 95                2.484584e-08                         0.000001
# 96                2.484584e-08                         0.000001
# 97                2.484584e-08                         0.000001
# 98                2.484584e-08                         0.000001
# 99                2.484584e-08                         0.000001
# 100               2.484584e-08                         0.000001
# 101               2.484584e-08                         0.000001
# 102               2.484584e-08                         0.000001
# 103               2.484584e-08                         0.000001
# 104               2.484584e-08                         0.000001
# 105               2.484584e-08                         0.000001
# 106               2.484584e-08                         0.000001
# 107               2.484584e-08                         0.000001
# 108               2.484584e-08                         0.000001
# 109               2.484584e-08                         0.000001
# 110               2.484584e-08                         0.000001
# 111               2.484584e-08                         0.000001
# 112               2.484584e-08                         0.000001
# 113               2.484584e-08                         0.000001
# 114               2.484584e-08                         0.000001
# 115               2.484584e-08                         0.000001
# 116               2.484584e-08                         0.000001
# 117               2.484584e-08                         0.000001
# 118               2.484584e-08                         0.000001
# 119               2.484584e-08                         0.000001
# 120               2.484584e-08                         0.000001
# 121               2.484584e-08                         0.000001
# 122               2.484584e-08                         0.000001
# 123               2.484584e-08                         0.000001
# 124               2.484584e-08                         0.000001
# 125               2.484584e-08                         0.000001
# 126               2.484584e-08                         0.000001
# 127               2.484584e-08                         0.000001
# 128               2.484584e-08                         0.000001
# 129               2.484584e-08                         0.000001
# 130               2.484584e-08                         0.000001
# 131               2.484584e-08                         0.000001
# 132               2.484584e-08                         0.000001
# 133               2.484584e-08                         0.000001
# 134               2.484584e-08                         0.000001
# 135               2.484584e-08                         0.000001
# 136               2.484584e-08                         0.000001
# 137               2.484584e-08                         0.000001
# 138               2.484584e-08                         0.000001
# 139               2.484584e-08                         0.000001
# 140               2.484584e-08                         0.000001
# 141               2.484584e-08                         0.000001
# 142               2.484584e-08                         0.000001
# 143               2.484584e-08                         0.000001
