# %%
microsimDir = "/Users/deligkaris.1/OneDrive - The Ohio State University Wexner Medical Center/MICROSIM/CODE/microsim"
#analysisDir = "/Users/burke.227/Documents/research/bpCog/primaryAnalyses"

# %%
# %matplotlib inline
# %autosave 120

import os
import matplotlib.pyplot as plt
os.chdir(microsimDir)
from microsim.population import NHANESDirectSamplePopulation
from microsim.population import Population

#from microsim.bp_treatment_strategies import *
#from microsim.outcome_model_repository import OutcomeModelRepository

import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
from microsim.outcome import Outcome, OutcomeType
from microsim.outcome_model_type import OutcomeModelType

import logging
logging.basicConfig(level=logging.INFO)

pd.options.display.float_format = '{:,.4f}'.format
# Out:
# Autosaving every 120 seconds

# %%
pop = NHANESDirectSamplePopulation(10000, year=1999)

# %%
# gcp does not appear here
pop._people.tolist()[0]
# Out:
# Person(age=71.0, gender=2, race/eth=1, sbp=155.3, dbp=72.0, a1c=6.4, hdl=36.0, totChol=185.0, bmi=36.5, ldl=115.0, trig=169.0, smoking=0, waist=114.4, anyPhysicalActivity=1, alcohol=0, education=1, antiHypertensiveCount=1.0, otherLipid=0.0, creatinine=0.5, statin=0.0, index=0, outcomes={<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []})

# %%
# but it is a person attribute
pop._people.tolist()[0]._gcp
# Out:
# [51.306942305069626]

# %%
#how to find out outcomes
pop._people.tolist()[0]._outcomes[OutcomeType.MI]
# Out:
# []

# %%
#remember this returns current state only!
df = pop.get_people_current_state_and_summary_as_dataframe()
# Out:
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/pandarallel/data_types/series.py:16: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   yield data[chunk_]

# %%
#current gcp, base Gcp and gcp slope are part of the dataframe
df.head()
# Out:
#       age  baseAge  gender  raceEthnicity  black      sbp     dbp    a1c  \
# 0 71.0000  71.0000       2              1  False 155.3333 72.0000 6.4000
# 1 76.0000  76.0000       1              3  False 152.0000 75.3333 5.5000
# 2 63.0000  63.0000       1              4   True 134.0000 78.0000 4.8000
# 3 32.0000  32.0000       1              3  False 121.3333 70.0000 5.2000
# 4 71.0000  71.0000       2              3  False 109.3333 51.3333 5.1000
#
#    current_diabetes      gfr     hdl      ldl     trig  totChol     bmi  \
# 0             False  97.6867 36.0000 115.0000 169.0000 185.0000 36.5000
# 1             False  72.7849 61.0000 156.0000 207.0000 252.0000 31.2000
# 2             False 104.7105 56.0000  86.0000 200.0000 182.0000 19.9000
# 3             False 124.8687 31.0000  63.0000  78.0000 119.0000 24.9900
# 4             False  97.6867 80.0000 103.0000 123.0000 208.0000 25.4300
#
#    anyPhysicalActivity  education   afib  alcoholPerWeek  creatinine  \
# 0                    1          1 0.0089               0      0.5000
# 1                    1          5 0.0095               3      1.0000
# 2                    1          2 0.0032               3      0.9000
# 3                    0          3 0.0012               3      0.7000
# 4                    0          3 0.0273               0      0.5000
#
#    antiHypertensiveCount  current_bp_treatment  statin  \
# 0                 1.0000                  True  0.0000
# 1                 0.0000                 False  0.0000
# 2                 0.0000                 False  0.0000
# 3                 1.0000                  True  1.0000
# 4                 1.0000                  True  0.0000
#
#    otherLipidLoweringMedicationCount    waist  smokingStatus  current_smoker  \
# 0                             0.0000 114.4000              0           False
# 1                             0.0000 117.1000              2            True
# 2                             0.0000  86.0000              0           False
# 3                             0.0000  93.7000              2            True
# 4                             0.0000  81.0000              0           False
#
#     dead  gcpRandomEffect  miPriorToSim     mi stroke  ageAtFirstStroke  \
# 0  False           9.6649             0  False  False               NaN
# 1  False           2.9886             0  False  False               NaN
# 2  False          -3.7034             0  False  False               NaN
# 3  False           3.8561             0  False  False               NaN
# 4  False           7.6051             0  False  False               NaN
#
#    ageAtFirstMI ageAtFirstDementia  miInSim  strokePriorToSim  strokeInSim  \
# 0           NaN               None    False                 0        False
# 1           NaN               None    False                 0        False
# 2           NaN               None    False                 0        False
# 3           NaN               None    False                 0        False
# 4           NaN               None    False                 0        False
#
#    dementia     gcp  baseGcp  gcpSlope  totalYearsInSim  totalQalys  \
# 0     False 51.3069  51.3069         0                0      0.9900
# 1     False 56.6476  56.6476         0                0      0.9400
# 2     False 35.5426  35.5426         0                0      1.0000
# 3     False 64.1441  64.1441         0                0      1.0000
# 4     False 72.9727  72.9727         0                0      0.9900
#
#    totalBPMedsAdded  bpMedsAdded  populationIndex     sbp0    dbp0   a1c0  \
# 0                 0            0                0 155.3333 72.0000 6.4000
# 1                 0            0                1 152.0000 75.3333 5.5000
# 2                 0            0                2 134.0000 78.0000 4.8000
# 3                 0            0                3 121.3333 70.0000 5.2000
# 4                 0            0                4 109.3333 51.3333 5.1000
#
#      hdl0     ldl0    trig0  totChol0    bmi0  anyPhysicalActivity0  afib0  \
# 0 36.0000 115.0000 169.0000  185.0000 36.5000                     1 0.0089
# 1 61.0000 156.0000 207.0000  252.0000 31.2000                     1 0.0095
# 2 56.0000  86.0000 200.0000  182.0000 19.9000                     1 0.0032
# 3 31.0000  63.0000  78.0000  119.0000 24.9900                     0 0.0012
# 4 80.0000 103.0000 123.0000  208.0000 25.4300                     0 0.0273
#
#     waist0  alcoholPerWeek0  creatinine0    age0  antiHypertensiveCount0  \
# 0 114.4000                0       0.5000 71.0000                  1.0000
# 1 117.1000                3       1.0000 76.0000                  0.0000
# 2  86.0000                3       0.9000 63.0000                  0.0000
# 3  93.7000                3       0.7000 32.0000                  1.0000
# 4  81.0000                0       0.5000 71.0000                  1.0000
#
#    statin0  bpMedsAdded0  meanSbp  meanDbp  meanA1c  meanHdl  meanLdl  \
# 0   0.0000             0 155.3333  72.0000   6.4000  36.0000 115.0000
# 1   0.0000             0 152.0000  75.3333   5.5000  61.0000 156.0000
# 2   0.0000             0 134.0000  78.0000   4.8000  56.0000  86.0000
# 3   1.0000             0 121.3333  70.0000   5.2000  31.0000  63.0000
# 4   0.0000             0 109.3333  51.3333   5.1000  80.0000 103.0000
#
#    meanTrig  meanTotchol  meanBmi  meanAnyphysicalactivity  meanAfib  \
# 0  169.0000     185.0000  36.5000                   1.0000    0.0089
# 1  207.0000     252.0000  31.2000                   1.0000    0.0095
# 2  200.0000     182.0000  19.9000                   1.0000    0.0032
# 3   78.0000     119.0000  24.9900                   0.0000    0.0012
# 4  123.0000     208.0000  25.4300                   0.0000    0.0273
#
#    meanWaist  meanAlcoholperweek  meanCreatinine  meanAge  \
# 0   114.4000              0.0000          0.5000  71.0000
# 1   117.1000              3.0000          1.0000  76.0000
# 2    86.0000              3.0000          0.9000  63.0000
# 3    93.7000              3.0000          0.7000  32.0000
# 4    81.0000              0.0000          0.5000  71.0000
#
#    meanAntihypertensivecount  meanStatin  meanBpmedsadded
# 0                     1.0000      0.0000           0.0000
# 1                     0.0000      0.0000           0.0000
# 2                     0.0000      0.0000           0.0000
# 3                     1.0000      1.0000           0.0000
# 4                     1.0000      0.0000           0.0000

# %%
df["gcp"].describe()

# %%
alive,df = pop.advance_vectorized(4)
# Out:
# /Users/deligkaris.1/Library/Caches/pypoetry/virtualenvs/microsim-54NoInYP-py3.9/lib/python3.9/site-packages/pandarallel/data_types/series.py:16: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   yield data[chunk_]
# INFO:root:processing year: 0
# INFO:root:processing year: 1
# /Users/deligkaris.1/Library/CloudStorage/OneDrive-TheOhioStateUniversityWexnerMedicalCenter/MICROSIM/CODE/microsim/microsim/gfr_equation.py:82: RuntimeWarning: invalid value encountered in double_scalars
#   return constant * (x.creatinine / crThreshold) ** exponent * 0.993**x.age
# INFO:root:processing year: 2
# /Users/deligkaris.1/Library/CloudStorage/OneDrive-TheOhioStateUniversityWexnerMedicalCenter/MICROSIM/CODE/microsim/microsim/gfr_equation.py:82: RuntimeWarning: invalid value encountered in double_scalars
#   return constant * (x.creatinine / crThreshold) ** exponent * 0.993**x.age
# INFO:root:processing year: 3
# /Users/deligkaris.1/Library/CloudStorage/OneDrive-TheOhioStateUniversityWexnerMedicalCenter/MICROSIM/CODE/microsim/microsim/gfr_equation.py:82: RuntimeWarning: invalid value encountered in double_scalars
#   return constant * (x.creatinine / crThreshold) ** exponent * 0.993**x.age

# %%
alive["gcp"].describe()

# %%
alive.iloc[0]

# %%
for i in range(100):
    print(i,pop._people.tolist()[i]._outcomes)
# Out:
# 0 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 1 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 2 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 3 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 4 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 5 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 6 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 7 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 8 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 9 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 10 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 11 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 12 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 13 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 14 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 15 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 16 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 17 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 18 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 19 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 20 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 21 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 22 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 23 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 24 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 25 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 26 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 27 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 28 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 29 {<OutcomeType.MI: 'mi'>: [(46.0, Outcome type: OutcomeType.MI, fatal: [False])], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 30 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 31 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 32 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [(-1, Outcome type: OutcomeType.STROKE, fatal: False)], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 33 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 34 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 35 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 36 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 37 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 38 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 39 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 40 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 41 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 42 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 43 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 44 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 45 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 46 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 47 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 48 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 49 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 50 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 51 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 52 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 53 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 54 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 55 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 56 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 57 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 58 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 59 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 60 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 61 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 62 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 63 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 64 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 65 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 66 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 67 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 68 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 69 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 70 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 71 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 72 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 73 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 74 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 75 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 76 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [(36.0, Outcome type: OutcomeType.STROKE, fatal: [False])], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 77 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [(66.0, Outcome type: OutcomeType.STROKE, fatal: [False])], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 78 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 79 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [(79.0, Outcome type: OutcomeType.STROKE, fatal: [ True])], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 80 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 81 {<OutcomeType.MI: 'mi'>: [(-1, Outcome type: OutcomeType.MI, fatal: False)], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 82 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 83 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 84 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 85 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 86 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 87 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 88 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 89 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 90 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 91 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 92 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 93 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 94 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 95 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 96 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 97 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 98 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}
# 99 {<OutcomeType.MI: 'mi'>: [], <OutcomeType.STROKE: 'stroke'>: [], <OutcomeType.DEMENTIA: 'dementia'>: []}

# %%
pop._people.tolist()[29]._outcomes
# Out:
# {<OutcomeType.MI: 'mi'>: [(46.0,
#    Outcome type: OutcomeType.MI, fatal: [False])],
#  <OutcomeType.STROKE: 'stroke'>: [],
#  <OutcomeType.DEMENTIA: 'dementia'>: []}

# %%
alive.iloc[29]
# Out:
# age                      89.0000
# baseAge                  85.0000
# gender                         1
# raceEthnicity                  3
# black                      False
#                            ...
# antiHypertensiveCount4         0
# statin4                    False
# mi4                        False
# stroke4                    False
# dead4                      False
# Name: 29, Length: 153, dtype: object
